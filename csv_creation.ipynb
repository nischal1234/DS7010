# %%
cd D:/DS7010/IEMOCAP_full_release/IEMOCAP_full_release
# Out:
# D:\DS7010\IEMOCAP_full_release\IEMOCAP_full_release

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 6E0F-DE97
#
#  Directory of D:\DS7010\IEMOCAP_full_release\IEMOCAP_full_release
#
# 13/04/2012  17:07    <DIR>          .
# 17/01/2024  09:49    <DIR>          ..
# 13/04/2012  16:45    <DIR>          Documentation
# 13/04/2012  17:07             4,725 README.txt
# 13/04/2012  17:07             4,728 README.txt~
# 13/04/2012  16:42    <DIR>          Session1
# 13/04/2012  16:42    <DIR>          Session2
# 13/04/2012  16:42    <DIR>          Session3
# 13/04/2012  16:42    <DIR>          Session4
# 13/04/2012  16:42    <DIR>          Session5
#                2 File(s)          9,453 bytes
#                8 Dir(s)  183,493,861,376 bytes free

# %%
import os
import re

# %%
# first test with one file
file_path = 'D:/DS7010/IEMOCAP_full_release/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro01.txt'

useful_regex = re.compile(r'\[.+\]\n', re.IGNORECASE)

# %%
with open(file_path) as f:
    file_content = f.read()
    
info_lines = re.findall(useful_regex, file_content)

for l in info_lines[1:10]:
    print(l.strip().split('\t'))
# Out:
# ['[6.2901 - 8.2357]', 'Ses01F_impro01_F000', 'neu', '[2.5000, 2.5000, 2.5000]']
# ['[10.0100 - 11.3925]', 'Ses01F_impro01_F001', 'neu', '[2.5000, 2.5000, 2.5000]']
# ['[14.8872 - 18.0175]', 'Ses01F_impro01_F002', 'neu', '[2.5000, 2.5000, 2.5000]']
# ['[19.2900 - 20.7875]', 'Ses01F_impro01_F003', 'xxx', '[2.5000, 3.0000, 3.0000]']
# ['[21.3257 - 24.7400]', 'Ses01F_impro01_F004', 'xxx', '[2.5000, 3.0000, 2.5000]']
# ['[27.4600 - 31.4900]', 'Ses01F_impro01_F005', 'neu', '[2.5000, 3.5000, 2.0000]']
# ['[38.9650 - 43.5900]', 'Ses01F_impro01_F006', 'fru', '[2.0000, 3.5000, 3.5000]']
# ['[46.5800 - 52.1900]', 'Ses01F_impro01_F007', 'fru', '[2.5000, 3.5000, 3.5000]']
# ['[56.1600 - 58.8225]', 'Ses01F_impro01_F008', 'fru', '[2.0000, 3.5000, 3.5000]']

# %%
info_line = re.compile(r'\[.+\]\n', re.IGNORECASE)

start_times, end_times, wav_file_names, emotions, vals, acts, doms = [], [], [], [], [], [], []

for sess in range(1, 6):
    emo_evaluation_dir = f'D:/DS7010/IEMOCAP_full_release/IEMOCAP_full_release/Session{sess}/dialog/EmoEvaluation/'
    evaluation_files = [l for l in os.listdir(emo_evaluation_dir) if '.txt' in l if not '._S' in l]
    print(f"Evaluation_files in Session {sess}: {len(evaluation_files)}")
    for file in evaluation_files:
        print("File name: ", file)
        with open(emo_evaluation_dir + file) as f:
            content = f.read()
        info_lines = re.findall(info_line, content)
        for line in info_lines[1:]:  # the first line is a header
            start_end_time, wav_file_name, emotion, val_act_dom = line.strip().split('\t')
            start_time, end_time = start_end_time[1:-1].split('-')
            val, act, dom = val_act_dom[1:-1].split(',')
            val, act, dom = float(val), float(act), float(dom)
            start_time, end_time = float(start_time), float(end_time)
            start_times.append(start_time)
            end_times.append(end_time)
            wav_file_names.append(wav_file_name)
            emotions.append(emotion)
            vals.append(val)
            acts.append(act)
            doms.append(dom)
# Out:
# Evaluation_files in Session 1: 28
# File name:  Ses01F_impro01.txt
# File name:  Ses01F_impro02.txt
# File name:  Ses01F_impro03.txt
# File name:  Ses01F_impro04.txt
# File name:  Ses01F_impro05.txt
# File name:  Ses01F_impro06.txt
# File name:  Ses01F_impro07.txt
# File name:  Ses01F_script01_1.txt
# File name:  Ses01F_script01_2.txt
# File name:  Ses01F_script01_3.txt
# File name:  Ses01F_script02_1.txt
# File name:  Ses01F_script02_2.txt
# File name:  Ses01F_script03_1.txt
# File name:  Ses01F_script03_2.txt
# File name:  Ses01M_impro01.txt
# File name:  Ses01M_impro02.txt
# File name:  Ses01M_impro03.txt
# File name:  Ses01M_impro04.txt
# File name:  Ses01M_impro05.txt
# File name:  Ses01M_impro06.txt
# File name:  Ses01M_impro07.txt
# File name:  Ses01M_script01_1.txt
# File name:  Ses01M_script01_2.txt
# File name:  Ses01M_script01_3.txt
# File name:  Ses01M_script02_1.txt
# File name:  Ses01M_script02_2.txt
# File name:  Ses01M_script03_1.txt
# ...

# %%
df_iemocap = pd.DataFrame(columns=['start_time', 'end_time', 'wav_file', 'emotion', 'val', 'act', 'dom'])

df_iemocap['start_time'] = start_times
df_iemocap['end_time'] = end_times
df_iemocap['wav_file'] = wav_file_names
df_iemocap['emotion'] = emotions
df_iemocap['val'] = vals
df_iemocap['act'] = acts
df_iemocap['dom'] = doms

df_iemocap
# Out:
#        start_time  end_time                wav_file emotion  val  act  dom
# 0          6.2901    8.2357     Ses01F_impro01_F000     neu  2.5  2.5  2.5
# 1         10.0100   11.3925     Ses01F_impro01_F001     neu  2.5  2.5  2.5
# 2         14.8872   18.0175     Ses01F_impro01_F002     neu  2.5  2.5  2.5
# 3         19.2900   20.7875     Ses01F_impro01_F003     xxx  2.5  3.0  3.0
# 4         21.3257   24.7400     Ses01F_impro01_F004     xxx  2.5  3.0  2.5
# ...           ...       ...                     ...     ...  ...  ...  ...
# 10034    236.5700  244.8300  Ses05M_script03_2_M041     ang  1.0  4.5  5.0
# 10035    244.8400  246.5800  Ses05M_script03_2_M042     ang  1.0  4.5  4.5
# 10036    246.5900  248.8300  Ses05M_script03_2_M043     ang  1.5  4.0  4.5
# 10037    255.8600  260.3300  Ses05M_script03_2_M044     ang  1.0  5.0  5.0
# 10038    260.3400  266.3500  Ses05M_script03_2_M045     ang  1.0  5.0  5.0
#
# [10039 rows x 7 columns]

# %%
data=pd.read_csv('iemocap_final.csv')
data
# Out:
#                             _id  activation  valence  dominance emotion  \
# 0      625699ea1da7a5c1eaef6e63         2.5      2.5        2.5     neu
# 1      625699ea1da7a5c1eaef6e65         2.5      2.5        2.5     neu
# 2      625699ea1da7a5c1eaef6e67         2.5      2.5        2.5     neu
# 3      625699ea1da7a5c1eaef6e69         3.0      2.5        3.0     neu
# 4      625699ea1da7a5c1eaef6e6a         3.0      2.5        2.5     neu
# ...                         ...         ...      ...        ...     ...
# 10034  6256899b1da7a5c1eaef47c4         4.5      1.0        5.0     ang
# 10035  6256899b1da7a5c1eaef47c6         4.5      1.0        4.5     ang
# 10036  6256899b1da7a5c1eaef47c8         4.0      1.5        4.5     ang
# 10037  6256899b1da7a5c1eaef47ca         5.0      1.0        5.0     ang
# 10038  6256899b1da7a5c1eaef47cc         5.0      1.0        5.0     ang
#
#        start_time  end_time                wav_file  \
# ...
